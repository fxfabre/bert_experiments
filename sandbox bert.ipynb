# %%
import torch
from torch.utils.data import DataLoader
from torch.utils.data import SequentialSampler
from torch.utils.data import TensorDataset
from transformers import AutoModel
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')
#
# File /usr/local/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py:457, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     454     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     456 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# --> 457 tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#     458 config_tokenizer_class = tokenizer_config.get("tokenizer_class")
#     460 # If that did not work, let's try to use the config.
#
# File /usr/local/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py:323, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, **kwargs)
#     317     config_file = hf_bucket_url(
#     318         pretrained_model_name_or_path, filename=TOKENIZER_CONFIG_FILE, revision=revision, mirror=None
#     319     )
#     321 try:
#     322     # Load from URL or cache if already cached
# --> 323     resolved_config_file = cached_path(
#     324         config_file,
#     325         cache_dir=cache_dir,
#     326         force_download=force_download,
#     327         proxies=proxies,
#     328         resume_download=resume_download,
#     329         local_files_only=local_files_only,
#     330         use_auth_token=use_auth_token,
#     331     )
#     333 except EnvironmentError:
#     334     logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File /usr/local/lib/python3.8/site-packages/transformers/file_utils.py:1402, in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1398     local_files_only = True
#    1400 if is_remote_url(url_or_filename):
#    1401     # URL, so get it from the cache (downloading if necessary)
# -> 1402     output_path = get_from_cache(
#    1403         url_or_filename,
#    1404         cache_dir=cache_dir,
#    1405         force_download=force_download,
#    1406         proxies=proxies,
#    1407         resume_download=resume_download,
#    1408         user_agent=user_agent,
#    1409         use_auth_token=use_auth_token,
#    1410         local_files_only=local_files_only,
#    1411     )
#    1412 elif os.path.exists(url_or_filename):
#    1413     # File, and it exists.
#    1414     output_path = url_or_filename
#
# File /usr/local/lib/python3.8/site-packages/transformers/file_utils.py:1666, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1663 with temp_file_manager() as temp_file:
#    1664     logger.info(f"{url} not found in cache or force_download set to True, downloading to {temp_file.name}")
# -> 1666     http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1668 logger.info(f"storing {url} in cache at {cache_path}")
#    1669 os.replace(temp_file.name, cache_path)
#
# File /usr/local/lib/python3.8/site-packages/transformers/file_utils.py:1516, in http_get(url, temp_file, proxies, resume_size, headers)
#    1514 content_length = r.headers.get("Content-Length")
#    1515 total = resume_size + int(content_length) if content_length is not None else None
# -> 1516 progress = tqdm(
#    1517     unit="B",
#    1518     unit_scale=True,
#    1519     unit_divisor=1024,
#    1520     total=total,
#    1521     initial=resume_size,
#    1522     desc="Downloading",
#    1523     disable=bool(logging.get_verbosity() == logging.NOTSET),
#    1524 )
#    1525 for chunk in r.iter_content(chunk_size=1024):
#    1526     if chunk:  # filter out keep-alive new chunks
#
# File /usr/local/lib/python3.8/site-packages/tqdm/notebook.py:242, in tqdm_notebook.__init__(self, *args, **kwargs)
#     240 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241 total = self.total * unit_scale if self.total else self.total
# --> 242 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243 self.container.pbar = proxy(self)
#     244 self.displayed = False
#
# File /usr/local/lib/python3.8/site-packages/tqdm/notebook.py:115, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     106 # Fallback to text bar if there's no total
#     107 # DEPRECATED: replaced with an 'info' style bar
#     108 # if not total:
#    (...)
#     112
#     113 # Prepare IPython progress bar
#     114 if IProgress is None:  # #187 #451 #558 #872
# --> 115     raise ImportError(
#     116         "IProgress not found. Please update jupyter and ipywidgets."
#     117         " See https://ipywidgets.readthedocs.io/en/stable"
#     118         "/user_install.html")
#     119 if total:
#     120     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
